# %% [markdown]
# # MACHINE LEARNING AN END TO END SOLUTION: Section 0
# # Loan Application
# Presented by Shaun &copy; 2018
#
# ## Getting Started!

# %% [markdown]
# ## Installing Anaconda
#
#
# **Install Anaconda:** [Install Anaconda distribution](https://www.anaconda.com/download/)  **Windows, Apple and Linux Supported!!!**
# ![Anaconda](img/anacondainstall.jpg)
#
#
# ### Jupyter Quick Start Documentation:
#
# - [Jupyter Notebook quickstart](http://jupyter.readthedocs.io/en/latest/content-quickstart.html)
# <img src="img/jupana.png" alt="Drawing" style="width: 200px;"/>

# %% [markdown]
# ### Run Code:
# To run the code in Jupyter, put the mouse pointer on a cell and hit the run button on the toolbar as highlighted in yellow!
#
# ![Anaconda](img/run.jpg)
#
#
# **Review the toolbar and  menu options and keyboard shortcuts available as below:**
#
# ### Keyboard shortcuts:
#
# **Command mode** (gray border)
#
# - Create new cells above (**a**) or below (**b**) the current cell
# - Navigate using the **up arrow** and **down arrow**
# - Convert the cell type to Markdown (**m**) or code (**y**)
# - See keyboard shortcuts using **h**
# - Switch to Edit mode using **Enter**
#
# **Edit mode** (green border)
#
# - **Ctrl+Enter** to run a cell
# - Switch to Command mode using **Esc**
#
#
#
# ### Let's get started!
# ###### Importing Necessary Libraries
#
# This is how you import libaries and display each libary version, read more about some of the libraries below:
#
# 1. *Scikit-learn, Machine Learning in Python, Simple and efficient tools for data mining and data analysis:*  __[Scikit-learn ](http://scikit-learn.org/)__
#
# 2. *Pandas is an open source, BSD-licensed library providing high-performance, easy-to-use data structures and data analysis tools for the Python programming language:*   __[Pandas](https://pandas.pydata.org/)__
#
# 3. *NumPy is the fundamental package for scientific computing with Python:* __[Numpy](http://www.numpy.org/)__
#
# 4. *Matplotlib is a Python 2D plotting library which produces publication quality figures in a variety of hardcopy formats and interactive environments across platforms:*  __[Matplotlib](https://matplotlib.org/index.html#)__

# %%
# scikit-learn
import sklearn
print('sklearn: %s' % sklearn.__version__)
# pandas
import pandas as pd
print('pandas: %s' % pandas.__version__)
# numpy
import numpy as np
print('numpy: %s' % numpy.__version__)
# matplotlib
import matplotlib
print('matplotlib: %s' % matplotlib.__version__)
# Out:
# sklearn: 0.19.2
# pandas: 0.23.4
# numpy: 1.15.1
# matplotlib: 2.2.3

# %% [markdown]
# ### Load the Data Set Using Pandas
#
# *In the following cells, we will import our dataset from a .csv using the excellent library **Pandas**. This will load the data into a 2D array dataFrame that can then be analysed. Think of a dataframe as a table or excel spreadsheet with rows and columns*
#
# #### We load the dataset from the csv file using pandas pd
# 1. *We load the data into a DataFrame called **df** which will hold the dataset we load, feel free to call it a name you want*
# 2. *The dataset: LoanData.csv, is placed on the c: drive in a folder called ml.*
# 3. *Run **pd.read_csv(name and location of file here)** to load a dataset*

# %%
df = pd.read_csv('c:\\ml\\LoanData.csv')

# %% [markdown]
# ###  Explore the Data using Pandas head function
# *We will begin exploring the dataset, we will use Pandas' head function. By default the top 5 rows will be returned, by adjusting the value in the brackets as so:*  **head(20)** *will return,the top 20 observations(rows).*

# %%
df.head(20) #### return the top 20 observations and see the types of data present
# Out:
#     Loanid  Gender Marital_Status  Dependents Graduate Employed  \
# 0        1    Male             NO           0       NO      YES
# 1        2    Male            YES           1      YES      YES
# 2        3    Male            YES           0      YES      YES
# 3        4    Male            YES           0       NO      YES
# 4        5    Male             NO           0      YES      YES
# 5        6    Male            YES           2      YES      YES
# 6        7    Male            YES           0       NO      YES
# 7        8    Male            YES           3      YES       NO
# 8        9    Male            YES           2      YES      YES
# 9       10    Male            YES           1      YES      YES
# 10      11    Male            YES           2      YES      YES
# 11      12    Male            YES           2      YES      YES
# 12      13    Male            YES           2      YES      YES
# 13      14    Male             NO           0      YES       NO
# ...

# %% [markdown]
# ### Well done! This Section is completed!!!  Lets move and start Section 1.
